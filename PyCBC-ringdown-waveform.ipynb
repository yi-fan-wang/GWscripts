# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

fig_width_pt = 3*246.0  # Get this from LaTeX using \showthe\columnwidth
inches_per_pt = 1.0/72.27               # Convert pt to inch
golden_mean = (np.sqrt(5)-1.0)/2.0         # Aesthetic ratio
fig_width = fig_width_pt*inches_per_pt  # width in inches
fig_height = fig_width*golden_mean      # height in inches
fig_size =  [fig_width,fig_height]

params = { 'axes.labelsize': 24,
          'font.family': 'serif',
          'font.serif': 'Computer Modern Raman',
          'font.size': 24,
          'legend.fontsize': 20,
          'xtick.labelsize': 24,
          'ytick.labelsize': 24,
          'axes.grid' : True,
          'text.usetex': True,
          'savefig.dpi' : 100,
          'lines.markersize' : 14,
          'figure.figsize': fig_size}

mpl.rcParams.update(params)

# %%
from pycbc.waveform import ringdown

# %% [markdown]
# # Fundamental Modes

# %%
for mass in [60.,200]:
    for spin in [0.5]:
        pars = {'taper': True,
        'final_mass': mass,
        'final_spin': spin,
        'lmns': ['221'],
        'amp220': 1.e-21, 
        'amp210': 0, 
        'phi220': 0.,
        'phi210': 0,
        'inclination': 0}
        hp, _ = ringdown.get_td_from_final_mass_spin(template='TdQNMfromFinalMassSpin', **pars)
        plt.plot(hp.sample_times, hp,label='$M_f=$' + str(int(mass))+'$M_\odot,~ a_f$='+str(spin))

plt.xlim(-0.01,0.06)
plt.ylim(-1e-21,1e-21)
plt.xlabel('Time [s]')
plt.ylabel('Strain')
plt.legend()
plt.savefig('/home/astro/Nutstore/0-SH-Template-Thesis/figures/qnm1.png',bbox_inches='tight')
plt.show()

# %%
for mass in [60.]:
    for spin in [0.5,0.99]:
        pars = {'taper': True,
        'final_mass': mass,
        'final_spin': spin,
        'lmns': ['221'],
        'amp220': 1.e-21, 
        'amp210': 0, 
        'phi220': 0.,
        'phi210': 0,
        'inclination': 0}
        hp, _ = ringdown.get_td_from_final_mass_spin(template='TdQNMfromFinalMassSpin', **pars)
        plt.plot(hp.sample_times, hp,label='$M_f=$' + str(int(mass))+'$M_\odot,~ a_f$='+str(spin))

plt.xlim(-0.01,0.06)
plt.ylim(-1e-21,1e-21)
plt.xlabel('Time [s]')
plt.ylabel('Strain')
plt.legend()
plt.savefig('/home/astro/Nutstore/0-SH-Template-Thesis/figures/qnm2.png',bbox_inches='tight')
plt.show()

# %% [markdown]
# # Subdominant modes
# ### Note that the subdominant modes would not appear if the inclination angle = 0

# %%
pars_no_21 = {'taper': True,
        'final_mass': 60.,
        'final_spin': 0.7,
        'lmns': ['221'],
        'amp220': 1.e-21, 
        'phi220': 0.,
        'inclination': 0.}
hp_no_21, _ = ringdown.get_td_from_final_mass_spin(template='TdQNMfromFinalMassSpin', **pars_no_21)

# %%
plt.plot(hp.sample_times, hp, label='ringdown')
plt.plot(hp_no_21.sample_times, hp_no_21, label=u'no_21')
plt.ylim(-1e-21,1e-21)
plt.xlabel('Time [s]')
plt.ylabel('Strain')
plt.legend()
plt.show()
